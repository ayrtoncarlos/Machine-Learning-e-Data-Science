# %%
# %matplotlib inline
# %config InlineBackend.figure_format='svg'
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as dates
import seaborn
import datetime as dt

# %%
df = pd.read_csv("ppz-jan-fev-2017.csv")

# %%
df.head()
# Out:
#    hour  views
# 0     0      9
# 1     1      0
# 2     2      1
# 3     3      2
# 4     4      4

# %%
df.tail()
# Out:
#       hour  views
# 1411  1411     55
# 1412  1412     55
# 1413  1413      9
# 1414  1414     39
# 1415  1415     15

# %%
def to_date(value):
    
    return dt.datetime(2017, 1, 1) + dt.timedelta(hours=value)

df["date"] = df["hour"].apply(to_date)

# %%
df.head()
# Out:
#    hour  views                date
# 0     0      9 2017-01-01 00:00:00
# 1     1      0 2017-01-01 01:00:00
# 2     2      1 2017-01-01 02:00:00
# 3     3      2 2017-01-01 03:00:00
# 4     4      4 2017-01-01 04:00:00

# %%
del df["hour"]

# %%
df.tail()
# Out:
#       views                date
# 1411     55 2017-02-28 19:00:00
# 1412     55 2017-02-28 20:00:00
# 1413      9 2017-02-28 21:00:00
# 1414     39 2017-02-28 22:00:00
# 1415     15 2017-02-28 23:00:00

# %%
df.set_index(["date"], inplace=True)

# %%
df.head()
# Out:
#                      views
# date
# 2017-01-01 00:00:00      9
# 2017-01-01 01:00:00      0
# 2017-01-01 02:00:00      1
# 2017-01-01 03:00:00      2
# 2017-01-01 04:00:00      4

# %%
fig, ax = plt.subplots()
ax.plot_date(df.index.to_pydatetime(), df["views"], "b-")
ax.xaxis.set_minor_locator(dates.DayLocator(bymonthday=range(5, 32, 5)))
ax.xaxis.set_minor_formatter(dates.DateFormatter("%d"))
ax.xaxis.grid(True, which="minor")
ax.yaxis.grid()
ax.xaxis.set_major_locator(dates.MonthLocator())
ax.xaxis.set_major_formatter(dates.DateFormatter("%b"))
plt.tight_layout()
plt.show()

# %%
import locale

# %%
locale.setlocale(locale.LC_ALL, 'pt_BR')
# Out:
# ---------------------------------------------------------------------------
# Error                                     Traceback (most recent call last)
# <ipython-input-20-24f4eb67201f> in <module>()
# ----> 1 locale.setlocale(locale.LC_ALL, 'pt_BR')
#
# C:\Users\Bitão\Anaconda3\lib\locale.py in setlocale(category, locale)
#     596         # convert to string
#     597         locale = normalize(_build_localename(locale))
# --> 598     return _setlocale(category, locale)
#     599
#     600 def resetlocale(category=LC_ALL):
#
# Error: unsupported locale setting

# %%
fig, ax = plt.subplots()
ax.plot_date(df.index.to_pydatetime(), df["views"], "b-")
ax.xaxis.set_minor_locator(dates.DayLocator(bymonthday=range(5, 32, 5), interval=2))
ax.xaxis.set_minor_formatter(dates.DateFormatter("%d"))
ax.xaxis.grid(True, which="minor")
ax.yaxis.grid()
ax.xaxis.set_major_locator(dates.MonthLocator())
ax.xaxis.set_major_formatter(dates.DateFormatter("%b"))
plt.tight_layout()
plt.show()
